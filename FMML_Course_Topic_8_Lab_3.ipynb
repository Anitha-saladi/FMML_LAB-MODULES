# %% [markdown]
# <a href="https://colab.research.google.com/github/Anitha-saladi/FMML_LAB-MODULES/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 7478   1801.03329v2  We consider the task of weakly supervised one-...  stat
# 24491   1404.4316v1  This paper addresses the challenge of establis...    cs
# 21112  1708.01035v1  We study a novel outlier detection problem tha...    cs
# 29006  1708.02108v3  Weakly supervised semantic segmentation and lo...    cs
# 39007  1503.03606v1  In this paper, we present a novel approach for...    cs
# ...             ...                                                ...   ...
# 21917  1502.06689v1  We consider the problem of noisy 1-bit matrix ...  stat
# 14263  1504.07218v2  This paper explores the preference-based top-$...    cs
# 15405   1412.2442v1  Universal Grammar (UG) theory has been one of ...    cs
# 29208  1708.07522v1  The ability to accurately detect and classify ...    cs
# 22355  1603.03805v2  This paper investigates the phase retrieval pr...  stat
#
#                                                    title  year  \
# 7478   Weakly Supervised One-Shot Detection with Atte...  2018
# 24491  Generic Object Detection With Dense Neural Pat...  2014
# 21112    Detection of Abnormal Input-Output Associations  2017
# 29006  Two-Phase Learning for Weakly Supervised Objec...  2017
# 39007  Low-Level Features for Image Retrieval Based o...  2015
# ...                                                  ...   ...
# 21917  1-Bit Matrix Completion under Exact Low-Rank C...  2015
# 14263  Spectral MLE: Top-$K$ Rank Aggregation from Pa...  2015
# 15405  Rediscovering the Alphabet - On the Innate Uni...  2014
# 29208  SPARCNN: SPAtially Related Convolutional Neura...  2017
# 22355  Median-Truncated Nonconvex Approach for Phase ...  2016
#
#                                                 keywords
# 7478   [supervised, detection, detection, existence, ...
# 24491  [addresses, challenge, establishing, convoluti...
# 21112  [detection, associations, instances, dimension...
# 29006  [supervised, segmentation, important, fundamen...
# 39007  [retrieval, extraction, techniques, directiona...
# ...                                                  ...
# 21917  [completion, constraint, underlying, observing...
# 14263  [preference, aggregation, collection, repeated...
# 15405  [universal, important, linguistics, introduced...
# 29208  [accurately, cluttered, applications, detectio...
# 22355  [investigates, retrieval, magnitudes, measurem...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 7478     [supervised, detection, detection, existence, ...
# 24491    [addresses, challenge, establishing, convoluti...
# 21112    [detection, associations, instances, dimension...
# 29006    [supervised, segmentation, important, fundamen...
# 39007    [retrieval, extraction, techniques, directiona...
#                                ...
# 11021    [concerned, probability, distribution, minimiz...
# 21968    [asymptotic, trajectory, stochastic, approxima...
# 39607    [autonomous, monitoring, resolution, precision...
# 26952    [framework, segmenting, appearance, informatio...
# 21562    [correspondence, different, unsupervised, summ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8707 words.
# Out of those 4569 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4d99afe8-d245-418f-834f-2da524ed3acd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4d99afe8-d245-418f-834f-2da524ed3acd")) {                    Plotly.newPlot(                        "4d99afe8-d245-418f-834f-2da524ed3acd",                        [{"x":["existence","computing","representation","supervised","utterances","performance","including","mechanism","different","representations","architectural","considerably","outperforms","detection","precision","incorporated","developments","attention","similarity","architecture","conditioned","demonstrated","introduce","framework","conventional","challenge","discriminatively","establishing","addresses","dramatically","effectiveness","convolutional","efficient","frameworks","demonstrate","decomposable","instances","associations","probabilistic","identifying","dimensional","conditional","experimental","multivariate","analyzing","techniques","inference","combining","fundamentally","performed","activations","discriminative","segmentation","localization","prediction","important","transformed","neighbourhood","technique","surrounding","therefore","neighbours","individually","relationship","transform","directional","direction","retrieval","histogram","databases","considers","descriptor","represents","extraction","decomposed","gradients","evaluation","extracted","information","corroborate","typically","estimator","deterministic","lightweight","likelihood","empirical","incomplete","parallelizable","challenges","prominent","minimization","classification","established","quantization","categorical","sketching","alternates","dimensionality","majorization","streaming","acquisition","procedure","predictive","paramount","structure","thresholds","regularized","recursively","iteration","resultant","asymptotic","algorithms","sublinear","importance","stationary","recommendation","convergence","alternating","simulated","quantized","leveraging","synthetic","intrinsic","knowledge","providing","constituent","baselines","unconstrained","processing","percentages","differing","individual","environments","biologically","outperform","architectures","introduced","partition","analogous","unsupervised","depending","sophisticated","generalising","operation","augmentation","maintaining","periodically","availability","injection","specialised","significantly","connections","ensembles","hypothesis","misspecification","theoretical","alternatives","uncertainty","specifically","components","confidence","inferential","exponentially","estimators","generalize","numerical","characterize","introducing","conducted","applications","generalized","developed","parameters","applicable","functions","guarantees","establish","distributions","statistic","assessment","furthermore","penalized","perspective","construct","connection","coarsening","illustrate","variables","manipulations","constructed","observational","manipulator","experiments","generalizes","definition","automatically","correlate","generation","adversarial","improvement"],"y":[38,124,404,186,16,871,272,100,751,257,14,25,262,347,73,19,23,151,153,236,24,102,331,546,111,156,7,16,57,20,201,415,467,32,578,4,101,10,174,63,182,97,381,25,66,389,206,108,10,133,20,94,185,72,231,358,19,6,252,10,138,4,5,73,70,16,69,111,25,61,33,18,47,134,6,31,288,125,693,4,92,29,37,11,61,145,41,3,131,16,88,515,51,18,21,3,8,44,1,15,41,122,49,2,339,6,51,9,41,10,22,601,7,99,17,28,125,26,65,7,41,150,42,341,89,7,57,23,311,1,7,135,82,11,103,122,127,22,12,150,32,27,4,37,25,38,4,27,4,3,277,56,17,56,0,154,23,88,171,105,32,0,21,13,53,88,34,60,71,447,69,203,251,54,209,53,40,103,6,49,184,5,71,77,38,2,81,130,6,59,11,2,626,23,53,197,5,122,92,151],"type":"bar"},{"x":["existence","computing","representation", ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4569,), (4569, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7716666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.5272727272727273);'>Integrating</span> <span style=''>Logical</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Probabilistic</span> <span style='background-color:rgba(0, 255, 0, 0.801418439716312);'>Reasoning</span> <span style=''>for</span> <span style=''>Decision</span> <span style=''>Making</span> <br/><br/><span style=''>We</span> <span style=''>describe</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.4275618374558303);'>representation</span> <span style=''>and</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>methods</span> <span style=''>that</span> <span style=''>combine</span> <span style=''>logic</span> <span style='background-color:rgba(0, 255, 0, 0.37349397590361444);'>programming</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.37066666666666664);'>representations</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>uncertainty</span> <span style=''>(influence</span> <span style=''>diagrams)</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>emphasize</span> <span style=''>the</span> <span style=''>dynamic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construction</span> <span style=''>and</span> <span style=''>solution</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilistic</span> <span style=''>and</span> <span style=''>decision</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretic</span> <span style=''>models</span> <span style=''>for</span> <span style=''>complex</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666667);'>uncertain</span> <span style=''>domains</span> <span style=''>Given</span> <span style=''>a</span> <span style=''>query</span> <span style=''>a</span> <span style=''>logical</span> <span style=''>proof</span> <span style=''>is</span> <span style=''>produced</span> <span style=''>if</span> <span style=''>possible</span> <span style=''>if</span> <span style=''>not</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>influence</span> <span style=''>diagram</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>query</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3320312500000001);'>knowledge</span> <span style=''>of</span> <span style=''>the</span> <span style=''>decision</span> <span style=''>domain</span> <span style=''>is</span> <span style=''>produced</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subsequently</span> <span style=''>solved</span> <span style=''>A</span> <span style=''>uniform</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>declarative</span> <span style=''>first</span> <span style=''>order</span> <span style='background-color:rgba(0, 255, 0, 0.3320312500000001);'>knowledge</span> <span style='background-color:rgba(0, 255, 0, 0.4275618374558303);'>representation</span> <span style=''>is</span> <span style=''>combined</span> <span style=''>with</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.4457831325301205);'>integrated</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedures</span> <span style=''>for</span> <span style=''>logical</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Likelihood</span> <span style=''>Ratio</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Framework</span> <span style=''>for</span> <span style=''>High</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Semiparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Regression</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>ratio</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferential</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>semiparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalized</span> <span style=''>linear</span> <span style=''>models</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>addresses</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>data</span> <span style=''>analysis</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>incomplete</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>bias</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>heterogeneous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>multitask</span> <span style=''>learning</span> <span style=''>Our</span> <span style=''>work</span> <span style=''>has</span> <span style=''>three</span> <span style=''>main</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contributions</span> <span style=''>(i)</span> <span style=''>We</span> <span style=''>develop</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>chromatography</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>infer</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>of</span> <span style=''>interest</span> <span style=''>under</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>semiparametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalized</span> <span style=''>linear</span> <span style=''>model</span> <span style=''>without</span> <span style=''>the</span> <span style=''>need</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimating</span> <span style=''>the</span> <span style=''>unknown</span> <span style=''>base</span> <span style=''>measure</span> <span style=''>function</span> <span style=''>(ii)</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>construct</span> <span style=''>post</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>confidence</span> <span style=''>regions</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Pseudo</span> <span style='background-color:rgba(255, 0, 0, 0.5307692307692308);'>likelihood</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>community</span> <span style='background-color:rgba(0, 255, 0, 0.5219298245614035);'>detection</span> <span style=''>in</span> <span style=''>large</span> <span style=''>sparse</span> <span style=''>networks</span> <br/><br/><span style=''>Many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>for</span> <span style=''>fitting</span> <span style=''>network</span> <span style=''>models</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>communities</span> <span style=''>but</span> <span style=''>most</span> <span style=''>of</span> <span style=''>them</span> <span style=''>do</span> <span style=''>not</span> <span style=''>scale</span> <span style=''>well</span> <span style=''>to</span> <span style=''>large</span> <span style=''>networks</span> <span style=''>and</span> <span style=''>often</span> <span style=''>fail</span> <span style=''>on</span> <span style=''>sparse</span> <span style=''>networks</span> <span style=''>Here</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>new</span> <span style=''>fast</span> <span style=''>pseudo</span> <span style='background-color:rgba(255, 0, 0, 0.5307692307692308);'>likelihood</span> <span style=''>method</span> <span style=''>for</span> <span style=''>fitting</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3105134474327629);'>stochastic</span> <span style=''>block</span> <span style=''>model</span> <span style=''>for</span> <span style=''>networks</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>a</span> <span style=''>variant</span> <span style=''>that</span> <span style=''>allows</span> <span style=''>for</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>arbitrary</span> <span style=''>degree</span> <span style='background-color:rgba(255, 0, 0, 0.31283905967450276);'>distribution</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditioning</span> <span style=''>on</span> <span style=''>degrees</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>perform</span> <span style=''>well</span> <span style=''>under</span> <span style=''>a</span> <span style=''>range</span> <span style=''>of</span> <span style=''>settings</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>on</span> <span style=''>very</span> <span style=''>sparse</span> <span style=''>networks</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>illustrate</span> <span style=''>on</span> <span style=''>the</span> <span style=''>example</span> <span style=''>of</span> <span style=''>a</span> <span style=''>network</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>political</span> <span style=''>blogs</span> <span style=''>We</span> <span style=''>also</span> <span style=''>propose</span> <span style=''>spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>perturbations</span> <span style=''>a</span> <span style=''>method</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>independent</span> <span style=''>interest</span> <span style=''>which</span> <span style=''>works</span> <span style=''>well</span> <span style=''>on</span> <span style=''>sparse</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Short</span> <span style=''>term</span> <span style=''>time</span> <span style=''>series</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>using</span> <span style=''>Hilbert</span> <span style=''>space</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoregressive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <br/><br/><span style=''>Linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoregressive</span> <span style=''>models</span> <span style=''>serve</span> <span style=''>as</span> <span style=''>basic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>of</span> <span style=''>discrete</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Different</span> <span style=''>attempts</span> <span style=''>have</span> <span style=''>been</span> <span style=''>made</span> <span style=''>to</span> <span style=''>provide</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>versions</span> <span style=''>of</span> <span style=''>the</span> <span style=''>basic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoregressive</span> <span style=''>process</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>versions</span> <span style=''>based</span> <span style=''>on</span> <span style=''>kernel</span> <span style=''>methods</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Motivated</span> <span style=''>by</span> <span style=''>the</span> <span style=''>powerful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>of</span> <span style=''>Hilbert</span> <span style=''>space</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embeddings</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>apply</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodology</span> <span style=''>for</span> <span style=''>the</span> <span style=''>kernel</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>embedding</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoregressive</span> <span style=''>process</span> <span style=''>of</span> <span style=''>order</span> <span style=''>p</span> <span style=''>By</span> <span style=''>doing</span> <span style=''>so</span> <span style=''>we</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>version</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoregressive</span> <span style=''>process</span> <span style=''>that</span> <span style=''>shows</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increased</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>over</span> <span style=''>the</span> <span style=''>linear</span> <span style=''>model</span> <span style=''>in</span> <span style=''>highly</span> <span style=''>complex</span> <span style=''>time</span> <span style=''>series</span> <span style=''>We</span> <span style=''>use</span> <span style=''>the</span> <span style=''>method</span> <span style=''>proposed</span> <span style=''>for</span> <span style=''>one</span> <span style=''>step</span> <span style=''>ahead</span> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13491501416430596)
# 	segmentation (0.06550991501416431)
# 	evaluation (0.10198300283286119)
# 	processing (0.11012747875354108)
# 	information (0.24539660056657223)
# 	representation (0.14305949008498584)
# 	detection (0.12287535410764873)
# 	different (0.2659348441926346)
# 	recognition (0.13845609065155806)
# 	convolutional (0.14695467422096317)
#
# Some Statistics words are:
# 	statistical (0.152834008097166)
# 	stochastic (0.13562753036437247)
# 	estimation (0.173582995951417)
# 	theoretical (0.14827935222672065)
# 	variables (0.14068825910931174)
# 	algorithm (0.39473684210526316)
# 	inference (0.1882591093117409)
# 	distribution (0.18370445344129555)
# 	dimensional (0.20040485829959515)
# 	regression (0.18724696356275303)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="d3f25e39-2464-4100-90b7-98fb45351354" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d3f25e39-2464-4100-90b7-98fb45351354")) {                    Plotly.newPlot(                        "d3f25e39-2464-4100-90b7-98fb45351354",                        [{"x":["existence","computing","representation","supervised","utterances","performance","including","mechanism","different","representations","architectural","considerably","outperforms","detection","precision","incorporated","developments","attention","similarity","architecture","conditioned","demonstrated","introduce","framework","conventional","challenge","discriminatively","establishing","addresses","dramatically","effectiveness","convolutional","efficient","frameworks","demonstrate","decomposable","instances","associations","probabilistic","identifying","dimensional","conditional","experimental","multivariate","analyzing","techniques","inference","combining","fundamentally","performed","activations","discriminative","segmentation","localization","prediction","important","transformed","neighbourhood","technique","surrounding","therefore","neighbours","individually","relationship","transform","directional","direction","retrieval","histogram","databases","considers","descriptor","represents","extraction","decomposed","gradients","evaluation","extracted","information","corroborate","typically","estimator","deterministic","lightweight","likelihood","empirical","incomplete","parallelizable","challenges","prominent","minimization","classification","established","quantization","categorical","sketching","alternates","dimensionality","majorization","streaming","acquisition","procedure","predictive","paramount","structure","thresholds","regularized","recursively","iteration","resultant","asymptotic","algorithms","sublinear","importance","stationary","recommendation","convergence","alternating","simulated","quantized","leveraging","synthetic","intrinsic","knowledge","providing","constituent","baselines","unconstrained","processing","percentages","differing","individual","environments","biologically","outperform","architectures","introduced","partition","analogous","unsupervised","depending","sophisticated","generalising","operation","augmentation","maintaining","periodically","availability","injection","specialised","significantly","connections","ensembles","hypothesis","misspecification","theoretical","alternatives","uncertainty","specifically","components","confidence","inferential","exponentially","estimators","generalize","numerical","characterize","introducing","conducted","applications","generalized","developed","parameters","applicable","functions","guarantees","establish","distributions","statistic","assessment","furthermore","penalized","perspective","construct","connection","coarsening","illustrate","variables","manipulations","constructed","observational","manipulator","experiments","generalizes","definition","automatically","correlate","generation","adversarial","improvement","generated","experience","generative","reinforcement","variations","initialize","beginning","sparsistent","validation","microarray","undirected","criterion","challenging","graphical","essentially","stability","estimation","empirically","competing","interpretation","regularization","selection","conditions","replicable","partially","dependent","simultaneously","estimating","parameter","procedures","probability","stochastic","quantitatively","likelihoods","attributes","integration","bidirectional","clustering","approximation","estimates","summation","sequential","sandwiched","accurately","posterior","difficult","obtaining","marginalizing","inferences","opponents","arguments","alignment","linguistic"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	misspecification
# 	inferential
# 	sparsistent
# 	replicable
# 	sandwiched
# 	marginalizing
# 	affinities
# 	confounder
# 	confounders
# 	identifiable
# 	resurgence
# 	uncharted
# 	uninformative
# 	exemplary
# 	multiplayer
# 	memberships
# 	photovoltaic
# 	inheriting
# 	insurance
# 	nontrivially
# Some words which never appear in Statistics papers:
# 	negotiation
# 	transcripts
# 	observers
# 	synthesizer
# 	describable
# 	saturated
# 	photographs
# 	plasticity
# 	memorized
# 	neuromorphic
# 	attractors
# 	laparoscopic
# 	cholecystectomy
# 	illumination
# 	orthographic
# 	magnification
# 	troublesome
# 	inseparable
# 	breakthroughs
# 	navigational

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0479441616629584e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7125
